# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
dataset = pd.read_csv("train.csv")

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
dataset['Sex'] = label_encoder.fit_transform(dataset['Sex'])
dataset['Embarked'] = label_encoder.fit_transform(dataset['Embarked'])

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked
# 0         A/5 21171   7.2500   NaN         2
# 1          PC 17599  71.2833   C85         0
# 2  STON/O2. 3101282   7.9250   NaN         2
# 3            113803  53.1000  C123         2
# 4            373450   8.0500   NaN         2

# %%
dataset.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dataset = dataset.drop(['PassengerId','Ticket','Cabin', 'Name'], axis = 1)

# %%
dataset.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 1         1       1    0  38.0      1      0  71.2833         0
# 2         1       3    0  26.0      0      0   7.9250         2
# 3         1       1    0  35.0      1      0  53.1000         2
# 4         0       3    1  35.0      0      0   8.0500         2

# %%
dataset.isnull().sum().sum()
# Out:
# 0

# %%
from sklearn import neighbors

# %%
#y = dataset['Pclass']
#x = dataset.drop(['Pclass'],axis =1)

# %%
#x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state = True)

# %%
knn = neighbors.KNeighborsClassifier(n_neighbors=3)

# %%
#knn.fit(x_train,y_train).score(x_test,y_test)
# Out:
# 0.8389513108614233

# %%
#y_pred = knn.predict(x_test)

# %%
#confusion_matrix(y_test,y_pred)
# Out:
# array([[ 64,   5,   2],
#        [  9,  32,  12],
#        [  2,  13, 128]], dtype=int64)

# %%
k = []
s = []

# %%
def knn():
    y = dataset['Pclass']
    x = dataset.drop(['Pclass'],axis =1)
   
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size =0.3, random_state=0)
    z = y_test.count()
    for i in range(1,z):
        knn = neighbors.KNeighborsClassifier(n_neighbors = i)
        k.append(i)
        
        print("--------------------------------------------------------------------------------------")
        print(f"K value is : ",i)
        

       # x_train, x_test, y_train, y_test = train_test_split(x, y, test_size =0.3, random_state=0)
        #z = y_test.count()
        model = knn.fit(x_train,y_train)
        pred = model.predict(x_test)
        
        score = model.score(x_test,y_test)
        s.append(score)
        
    
        print(f"\nAcuuracy Score when k is {i} ", score)
        print(f"Confusion matrix when k is {i}  \n", confusion_matrix(y_test, pred))

# %%
knn()
# Out:
# --------------------------------------------------------------------------------------
# K value is :  1
#
# Acuuracy Score when k is 1  0.8913857677902621
# Confusion matrix when k is 1
#  [[ 62   6   2]
#  [  3  37   9]
#  [  1   8 139]]
# --------------------------------------------------------------------------------------
# K value is :  2
#
# Acuuracy Score when k is 2  0.8651685393258427
# Confusion matrix when k is 2
#  [[ 67   2   1]
#  [  8  37   4]
#  [  4  17 127]]
# --------------------------------------------------------------------------------------
# K value is :  3
#
# Acuuracy Score when k is 3  0.8651685393258427
# Confusion matrix when k is 3
#  [[ 63   5   2]
#  [  7  28  14]
#  [  3   5 140]]
# --------------------------------------------------------------------------------------
# K value is :  4
#
# Acuuracy Score when k is 4  0.8239700374531835
# Confusion matrix when k is 4
#  [[ 61   7   2]
#  [  8  30  11]
#  [  4  15 129]]
# --------------------------------------------------------------------------------------
# K value is :  5
#
# Acuuracy Score when k is 5  0.8314606741573034
# Confusion matrix when k is 5
#  [[ 58  10   2]
#  [  7  28  14]
#  [  3   9 136]]
# --------------------------------------------------------------------------------------
# K value is :  6
#
# Acuuracy Score when k is 6  0.846441947565543
# Confusion matrix when k is 6
#  [[ 64   5   1]
#  [  7  32  10]
#  [  3  15 130]]
# --------------------------------------------------------------------------------------
# K value is :  7
#
# Acuuracy Score when k is 7  0.8426966292134831
# Confusion matrix when k is 7
#  [[ 59  10   1]
#  [  7  28  14]
#  [  3   7 138]]
# --------------------------------------------------------------------------------------
# K value is :  8
#
# Acuuracy Score when k is 8  0.850187265917603
# Confusion matrix when k is 8
#  [[ 61   8   1]
#  [  7  34   8]
#  [  3  13 132]]
# --------------------------------------------------------------------------------------
# K value is :  9
#
# Acuuracy Score when k is 9  0.846441947565543
# Confusion matrix when k is 9
#  [[ 60   8   2]
#  [  7  29  13]
#  [  3   8 137]]
# --------------------------------------------------------------------------------------
# K value is :  10
#
# Acuuracy Score when k is 10  0.8352059925093633
# Confusion matrix when k is 10
#  [[ 60   8   2]
#  [  7  31  11]
#  [  3  13 132]]
# --------------------------------------------------------------------------------------
# K value is :  11
#
# Acuuracy Score when k is 11  0.8202247191011236
# Confusion matrix when k is 11
#  [[ 60   9   1]
#  [  8  27  14]
#  [  6  10 132]]
# --------------------------------------------------------------------------------------
# K value is :  12
#
# Acuuracy Score when k is 12  0.8277153558052435
# Confusion matrix when k is 12
#  [[ 61   8   1]
#  [  8  28  13]
#  [  5  11 132]]
# --------------------------------------------------------------------------------------
# K value is :  13
#
# Acuuracy Score when k is 13  0.8277153558052435
# Confusion matrix when k is 13
#  [[ 60   9   1]
#  [  7  28  14]
#  [  5  10 133]]
# --------------------------------------------------------------------------------------
# K value is :  14
#
# Acuuracy Score when k is 14  0.8202247191011236
# Confusion matrix when k is 14
#  [[ 60   8   2]
#  [  8  27  14]
#  [  5  11 132]]
# --------------------------------------------------------------------------------------
# K value is :  15
#
# Acuuracy Score when k is 15  0.8127340823970037
# Confusion matrix when k is 15
#  [[ 60   7   3]
#  [  7  27  15]
#  [  5  13 130]]
# --------------------------------------------------------------------------------------
# K value is :  16
#
# Acuuracy Score when k is 16  0.8164794007490637
# Confusion matrix when k is 16
#  [[ 60   7   3]
#  [  7  28  14]
#  [  5  13 130]]
# --------------------------------------------------------------------------------------
# K value is :  17
#
# Acuuracy Score when k is 17  0.8164794007490637
# Confusion matrix when k is 17
#  [[ 60   7   3]
#  [  7  27  15]
#  [  5  12 131]]
# --------------------------------------------------------------------------------------
# K value is :  18
#
# Acuuracy Score when k is 18  0.8164794007490637
# Confusion matrix when k is 18
#  [[ 60   6   4]
#  [  7  27  15]
#  [  5  12 131]]
# --------------------------------------------------------------------------------------
# K value is :  19
#
# Acuuracy Score when k is 19  0.8202247191011236
# Confusion matrix when k is 19
#  [[ 60   6   4]
#  [  7  28  14]
#  [  5  12 131]]
# --------------------------------------------------------------------------------------
# K value is :  20
#
# Acuuracy Score when k is 20  0.8202247191011236
# Confusion matrix when k is 20
#  [[ 60   6   4]
#  [  7  29  13]
#  [  5  13 130]]
# --------------------------------------------------------------------------------------
# K value is :  21
#
# Acuuracy Score when k is 21  0.8127340823970037
# Confusion matrix when k is 21
#  [[ 60   7   3]
#  [  7  27  15]
#  [  5  13 130]]
# --------------------------------------------------------------------------------------
# K value is :  22
#
# Acuuracy Score when k is 22  0.797752808988764
# Confusion matrix when k is 22
#  [[ 61   6   3]
#  [  7  27  15]
#  [  9  14 125]]
# --------------------------------------------------------------------------------------
# K value is :  23
#
# Acuuracy Score when k is 23  0.8014981273408239
# Confusion matrix when k is 23
#  [[ 61   6   3]
#  [  7  27  15]
#  [  8  14 126]]
# --------------------------------------------------------------------------------------
# K value is :  24
#
# Acuuracy Score when k is 24  0.7940074906367042
# Confusion matrix when k is 24
#  [[ 62   5   3]
#  [  7  27  15]
#  [  9  16 123]]
# --------------------------------------------------------------------------------------
# K value is :  25
#
# Acuuracy Score when k is 25  0.797752808988764
# Confusion matrix when k is 25
#  [[ 62   6   2]
#  [  7  26  16]
#  [  9  14 125]]
# --------------------------------------------------------------------------------------
# K value is :  26
#
# Acuuracy Score when k is 26  0.7865168539325843
# Confusion matrix when k is 26
#  [[ 61   5   4]
#  [  7  25  17]
#  [  9  15 124]]
# --------------------------------------------------------------------------------------
# K value is :  27
#
# Acuuracy Score when k is 27  0.797752808988764
# Confusion matrix when k is 27
#  [[ 62   5   3]
#  [  7  26  16]
#  [  9  14 125]]
# --------------------------------------------------------------------------------------
# K value is :  28
#
# Acuuracy Score when k is 28  0.7827715355805244
# Confusion matrix when k is 28
#  [[ 62   5   3]
#  [  7  24  18]
#  [ 10  15 123]]
# --------------------------------------------------------------------------------------
# K value is :  29
#
# Acuuracy Score when k is 29  0.7790262172284644
# Confusion matrix when k is 29
#  [[ 62   5   3]
#  [  7  24  18]
#  [ 10  16 122]]
# --------------------------------------------------------------------------------------
# K value is :  30
#
# Acuuracy Score when k is 30  0.7790262172284644
# Confusion matrix when k is 30
#  [[ 62   5   3]
#  [  7  24  18]
#  [ 10  16 122]]
# --------------------------------------------------------------------------------------
# K value is :  31
#
# Acuuracy Score when k is 31  0.7865168539325843
# Confusion matrix when k is 31
#  [[ 62   5   3]
#  [  7  24  18]
#  [  9  15 124]]
# --------------------------------------------------------------------------------------
# K value is :  32
#
# Acuuracy Score when k is 32  0.7827715355805244
# Confusion matrix when k is 32
#  [[ 62   5   3]
#  [  7  23  19]
#  [  9  15 124]]
# --------------------------------------------------------------------------------------
# K value is :  33
#
# Acuuracy Score when k is 33  0.7902621722846442
# Confusion matrix when k is 33
#  [[ 62   5   3]
#  [  7  23  19]
#  [  9  13 126]]
# --------------------------------------------------------------------------------------
# K value is :  34
#
# Acuuracy Score when k is 34  0.7865168539325843
# Confusion matrix when k is 34
#  [[ 62   5   3]
#  [  7  24  18]
#  [ 10  14 124]]
# --------------------------------------------------------------------------------------
# K value is :  35
#
# Acuuracy Score when k is 35  0.7790262172284644
# Confusion matrix when k is 35
#  [[ 62   5   3]
#  [  7  22  20]
#  [ 10  14 124]]
# --------------------------------------------------------------------------------------
# K value is :  36
#
# Acuuracy Score when k is 36  0.7827715355805244
# Confusion matrix when k is 36
#  [[ 62   5   3]
#  [  7  23  19]
#  [ 10  14 124]]
# --------------------------------------------------------------------------------------
# K value is :  37
#
# Acuuracy Score when k is 37  0.7865168539325843
# Confusion matrix when k is 37
#  [[ 62   5   3]
#  [  7  22  20]
#  [  9  13 126]]
# --------------------------------------------------------------------------------------
# K value is :  38
#
# Acuuracy Score when k is 38  0.7902621722846442
# Confusion matrix when k is 38
#  [[ 62   5   3]
#  [  7  23  19]
#  [  9  13 126]]
# --------------------------------------------------------------------------------------
# K value is :  39
# Acuuracy Score when k is 39  0.7752808988764045
# Confusion matrix when k is 39
#  [[ 61   5   4]
#  [  7  19  23]
#  [  9  12 127]]
# --------------------------------------------------------------------------------------
# K value is :  40
#
# Acuuracy Score when k is 40  0.7902621722846442
# Confusion matrix when k is 40
#  [[ 62   5   3]
#  [  7  20  22]
#  [  7  12 129]]
# --------------------------------------------------------------------------------------
# K value is :  41
#
# Acuuracy Score when k is 41  0.7827715355805244
# Confusion matrix when k is 41
#  [[ 61   5   4]
#  [  7  19  23]
#  [  7  12 129]]
# --------------------------------------------------------------------------------------
# K value is :  42
#
# Acuuracy Score when k is 42  0.7865168539325843
# Confusion matrix when k is 42
#  [[ 61   5   4]
#  [  7  20  22]
#  [  7  12 129]]
# --------------------------------------------------------------------------------------
# K value is :  43
#
# Acuuracy Score when k is 43  0.7827715355805244
# Confusion matrix when k is 43
#  [[ 61   6   3]
#  [  7  19  23]
#  [  7  12 129]]
# --------------------------------------------------------------------------------------
# K value is :  44
#
# Acuuracy Score when k is 44  0.7865168539325843
# Confusion matrix when k is 44
#  [[ 61   7   2]
#  [  7  20  22]
#  [  7  12 129]]
# --------------------------------------------------------------------------------------
# K value is :  45
#
# Acuuracy Score when k is 45  0.7827715355805244
# Confusion matrix when k is 45
#  [[ 61   7   2]
#  [  7  19  23]
#  [  7  12 129]]
# --------------------------------------------------------------------------------------
# K value is :  46
#
# Acuuracy Score when k is 46  0.7865168539325843
# Confusion matrix when k is 46
#  [[ 61   7   2]
#  [  7  20  22]
#  [  7  12 129]]
# --------------------------------------------------------------------------------------
# K value is :  47
#
# Acuuracy Score when k is 47  0.7752808988764045
# Confusion matrix when k is 47
#  [[ 61   6   3]
#  [  7  17  25]
#  [  7  12 129]]
# --------------------------------------------------------------------------------------
# K value is :  48
#
# Acuuracy Score when k is 48  0.7752808988764045
# Confusion matrix when k is 48
#  [[ 61   6   3]
#  [  7  17  25]
#  [  7  12 129]]
# --------------------------------------------------------------------------------------
# K value is :  49
#
# Acuuracy Score when k is 49  0.7752808988764045
# Confusion matrix when k is 49
#  [[ 62   6   2]
#  [  7  16  26]
#  [  7  12 129]]
# --------------------------------------------------------------------------------------
# K value is :  50
#
# Acuuracy Score when k is 50  0.7715355805243446
# Confusion matrix when k is 50
#  [[ 61   7   2]
#  [  7  16  26]
#  [  7  12 129]]
# --------------------------------------------------------------------------------------
# K value is :  51
#
# Acuuracy Score when k is 51  0.7715355805243446
# Confusion matrix when k is 51
#  [[ 61   6   3]
#  [  7  14  28]
#  [  5  12 131]]
# --------------------------------------------------------------------------------------
# K value is :  52
#
# Acuuracy Score when k is 52  0.7715355805243446
# Confusion matrix when k is 52
#  [[ 61   7   2]
#  [  7  15  27]
#  [  7  11 130]]
# --------------------------------------------------------------------------------------
# K value is :  53
#
# Acuuracy Score when k is 53  0.7677902621722846
# Confusion matrix when k is 53
#  [[ 61   6   3]
#  [  7  12  30]
#  [  5  11 132]]
# --------------------------------------------------------------------------------------
# K value is :  54
#
# Acuuracy Score when k is 54  0.7677902621722846
# Confusion matrix when k is 54
#  [[ 61   6   3]
#  [  7  12  30]
#  [  5  11 132]]
# --------------------------------------------------------------------------------------
# K value is :  55
#
# Acuuracy Score when k is 55  0.7715355805243446
# Confusion matrix when k is 55
#  [[ 61   6   3]
#  [  7  12  30]
#  [  5  10 133]]
# --------------------------------------------------------------------------------------
# K value is :  56
#
# Acuuracy Score when k is 56  0.7752808988764045
# Confusion matrix when k is 56
#  [[ 62   5   3]
#  [  7  12  30]
#  [  5  10 133]]
# --------------------------------------------------------------------------------------
# K value is :  57
#
# Acuuracy Score when k is 57  0.7752808988764045
# Confusion matrix when k is 57
#  [[ 62   5   3]
#  [  7  12  30]
#  [  5  10 133]]
# --------------------------------------------------------------------------------------
# K value is :  58
#
# Acuuracy Score when k is 58  0.7677902621722846
# Confusion matrix when k is 58
#  [[ 60   5   5]
#  [  6  12  31]
#  [  5  10 133]]
# --------------------------------------------------------------------------------------
# K value is :  59
#
# Acuuracy Score when k is 59  0.7602996254681648
# Confusion matrix when k is 59
#  [[ 60   5   5]
#  [  6  11  32]
#  [  5  11 132]]
# --------------------------------------------------------------------------------------
# K value is :  60
#
# Acuuracy Score when k is 60  0.7640449438202247
# Confusion matrix when k is 60
#  [[ 60   5   5]
#  [  6  12  31]
#  [  5  11 132]]
# --------------------------------------------------------------------------------------
# K value is :  61
#
# Acuuracy Score when k is 61  0.7602996254681648
# Confusion matrix when k is 61
#  [[ 60   5   5]
#  [  6  11  32]
#  [  5  11 132]]
# --------------------------------------------------------------------------------------
# K value is :  62
#
# Acuuracy Score when k is 62  0.7602996254681648
# Confusion matrix when k is 62
#  [[ 60   5   5]
#  [  6  11  32]
#  [  5  11 132]]
# --------------------------------------------------------------------------------------
# K value is :  63
#
# Acuuracy Score when k is 63  0.7565543071161048
# Confusion matrix when k is 63
#  [[ 58   5   7]
#  [  6  11  32]
#  [  5  10 133]]
# --------------------------------------------------------------------------------------
# K value is :  64
#
# Acuuracy Score when k is 64  0.7565543071161048
# Confusion matrix when k is 64
#  [[ 58   6   6]
#  [  5  11  33]
#  [  5  10 133]]
# --------------------------------------------------------------------------------------
# K value is :  65
#
# Acuuracy Score when k is 65  0.7602996254681648
# Confusion matrix when k is 65
#  [[ 58   6   6]
#  [  5  11  33]
#  [  5   9 134]]
# --------------------------------------------------------------------------------------
# K value is :  66
#
# Acuuracy Score when k is 66  0.7565543071161048
# Confusion matrix when k is 66
#  [[ 57   6   7]
#  [  5  11  33]
#  [  5   9 134]]
# --------------------------------------------------------------------------------------
# K value is :  67
#
# Acuuracy Score when k is 67  0.7602996254681648
# Confusion matrix when k is 67
#  [[ 57   6   7]
#  [  5  11  33]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  68
#
# Acuuracy Score when k is 68  0.7602996254681648
# Confusion matrix when k is 68
#  [[ 57   6   7]
#  [  5  11  33]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  69
#
# Acuuracy Score when k is 69  0.7640449438202247
# Confusion matrix when k is 69
#  [[ 56   7   7]
#  [  5  11  33]
#  [  5   6 137]]
# --------------------------------------------------------------------------------------
# K value is :  70
#
# Acuuracy Score when k is 70  0.7640449438202247
# Confusion matrix when k is 70
#  [[ 57   6   7]
#  [  5  11  33]
#  [  5   7 136]]
# --------------------------------------------------------------------------------------
# K value is :  71
#
# Acuuracy Score when k is 71  0.7640449438202247
# Confusion matrix when k is 71
#  [[ 57   6   7]
#  [  5  11  33]
#  [  5   7 136]]
# --------------------------------------------------------------------------------------
# K value is :  72
#
# Acuuracy Score when k is 72  0.7565543071161048
# Confusion matrix when k is 72
#  [[ 56   7   7]
#  [  5  11  33]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  73
#
# Acuuracy Score when k is 73  0.7640449438202247
# Confusion matrix when k is 73
#  [[ 56   7   7]
#  [  5  11  33]
#  [  5   6 137]]
# --------------------------------------------------------------------------------------
# K value is :  74
#
# Acuuracy Score when k is 74  0.7677902621722846
# Confusion matrix when k is 74
#  [[ 57   6   7]
#  [  5  11  33]
#  [  5   6 137]]
# --------------------------------------------------------------------------------------
# K value is :  75
#
# Acuuracy Score when k is 75  0.7640449438202247
# Confusion matrix when k is 75
#  [[ 56   7   7]
#  [  5  11  33]
#  [  5   6 137]]
# --------------------------------------------------------------------------------------
# K value is :  76
#
# Acuuracy Score when k is 76  0.7677902621722846
# Confusion matrix when k is 76
#  [[ 56   7   7]
#  [  5  11  33]
#  [  5   5 138]]
# --------------------------------------------------------------------------------------
# K value is :  77
# Acuuracy Score when k is 77  0.7715355805243446
# Confusion matrix when k is 77
#  [[ 57   6   7]
#  [  5  11  33]
#  [  5   5 138]]
# --------------------------------------------------------------------------------------
# K value is :  78
#
# Acuuracy Score when k is 78  0.7640449438202247
# Confusion matrix when k is 78
#  [[ 56   5   9]
#  [  5  11  33]
#  [  5   6 137]]
# --------------------------------------------------------------------------------------
# K value is :  79
#
# Acuuracy Score when k is 79  0.7565543071161048
# Confusion matrix when k is 79
#  [[ 56   5   9]
#  [  5  11  33]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  80
#
# Acuuracy Score when k is 80  0.7565543071161048
# Confusion matrix when k is 80
#  [[ 55   6   9]
#  [  5  11  33]
#  [  5   7 136]]
# --------------------------------------------------------------------------------------
# K value is :  81
#
# Acuuracy Score when k is 81  0.7602996254681648
# Confusion matrix when k is 81
#  [[ 56   5   9]
#  [  5  11  33]
#  [  5   7 136]]
# --------------------------------------------------------------------------------------
# K value is :  82
#
# Acuuracy Score when k is 82  0.7602996254681648
# Confusion matrix when k is 82
#  [[ 57   4   9]
#  [  5  10  34]
#  [  5   7 136]]
# --------------------------------------------------------------------------------------
# K value is :  83
#
# Acuuracy Score when k is 83  0.7528089887640449
# Confusion matrix when k is 83
#  [[ 55   5  10]
#  [  5  10  34]
#  [  5   7 136]]
# --------------------------------------------------------------------------------------
# K value is :  84
#
# Acuuracy Score when k is 84  0.7528089887640449
# Confusion matrix when k is 84
#  [[ 55   5  10]
#  [  5  10  34]
#  [  5   7 136]]
# --------------------------------------------------------------------------------------
# K value is :  85
#
# Acuuracy Score when k is 85  0.7490636704119851
# Confusion matrix when k is 85
#  [[ 55   6   9]
#  [  5  10  34]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  86
#
# Acuuracy Score when k is 86  0.7490636704119851
# Confusion matrix when k is 86
#  [[ 55   6   9]
#  [  5  10  34]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  87
#
# Acuuracy Score when k is 87  0.7490636704119851
# Confusion matrix when k is 87
#  [[ 55   6   9]
#  [  5  10  34]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  88
#
# Acuuracy Score when k is 88  0.7453183520599251
# Confusion matrix when k is 88
#  [[ 54   6  10]
#  [  5  10  34]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  89
#
# Acuuracy Score when k is 89  0.7490636704119851
# Confusion matrix when k is 89
#  [[ 54   6  10]
#  [  5  10  34]
#  [  5   7 136]]
# --------------------------------------------------------------------------------------
# K value is :  90
#
# Acuuracy Score when k is 90  0.7565543071161048
# Confusion matrix when k is 90
#  [[ 54   5  11]
#  [  5  10  34]
#  [  5   5 138]]
# --------------------------------------------------------------------------------------
# K value is :  91
#
# Acuuracy Score when k is 91  0.7565543071161048
# Confusion matrix when k is 91
#  [[ 54   6  10]
#  [  5  10  34]
#  [  5   5 138]]
# --------------------------------------------------------------------------------------
# K value is :  92
#
# Acuuracy Score when k is 92  0.7565543071161048
# Confusion matrix when k is 92
#  [[ 54   6  10]
#  [  5  10  34]
#  [  5   5 138]]
# --------------------------------------------------------------------------------------
# K value is :  93
#
# Acuuracy Score when k is 93  0.7528089887640449
# Confusion matrix when k is 93
#  [[ 54   6  10]
#  [  5  10  34]
#  [  5   6 137]]
# --------------------------------------------------------------------------------------
# K value is :  94
#
# Acuuracy Score when k is 94  0.7528089887640449
# Confusion matrix when k is 94
#  [[ 54   5  11]
#  [  5  10  34]
#  [  5   6 137]]
# --------------------------------------------------------------------------------------
# K value is :  95
#
# Acuuracy Score when k is 95  0.7528089887640449
# Confusion matrix when k is 95
#  [[ 54   6  10]
#  [  5  10  34]
#  [  5   6 137]]
# --------------------------------------------------------------------------------------
# K value is :  96
#
# Acuuracy Score when k is 96  0.7565543071161048
# Confusion matrix when k is 96
#  [[ 55   4  11]
#  [  5  10  34]
#  [  5   6 137]]
# --------------------------------------------------------------------------------------
# K value is :  97
#
# Acuuracy Score when k is 97  0.7453183520599251
# Confusion matrix when k is 97
#  [[ 53   6  11]
#  [  5  10  34]
#  [  5   7 136]]
# --------------------------------------------------------------------------------------
# K value is :  98
#
# Acuuracy Score when k is 98  0.7565543071161048
# Confusion matrix when k is 98
#  [[ 54   6  10]
#  [  5  10  34]
#  [  5   5 138]]
# --------------------------------------------------------------------------------------
# K value is :  99
#
# Acuuracy Score when k is 99  0.7378277153558053
# Confusion matrix when k is 99
#  [[ 53   6  11]
#  [  5  10  34]
#  [  5   9 134]]
# --------------------------------------------------------------------------------------
# K value is :  100
#
# Acuuracy Score when k is 100  0.7378277153558053
# Confusion matrix when k is 100
#  [[ 53   6  11]
#  [  5  10  34]
#  [  5   9 134]]
# --------------------------------------------------------------------------------------
# K value is :  101
#
# Acuuracy Score when k is 101  0.7303370786516854
# Confusion matrix when k is 101
#  [[ 53   6  11]
#  [  5  10  34]
#  [  5  11 132]]
# --------------------------------------------------------------------------------------
# K value is :  102
#
# Acuuracy Score when k is 102  0.7303370786516854
# Confusion matrix when k is 102
#  [[ 53   5  12]
#  [  5  10  34]
#  [  5  11 132]]
# --------------------------------------------------------------------------------------
# K value is :  103
#
# Acuuracy Score when k is 103  0.7340823970037453
# Confusion matrix when k is 103
#  [[ 53   7  10]
#  [  6  10  33]
#  [  5  10 133]]
# --------------------------------------------------------------------------------------
# K value is :  104
#
# Acuuracy Score when k is 104  0.7340823970037453
# Confusion matrix when k is 104
#  [[ 53   7  10]
#  [  6  10  33]
#  [  5  10 133]]
# --------------------------------------------------------------------------------------
# K value is :  105
#
# Acuuracy Score when k is 105  0.7378277153558053
# Confusion matrix when k is 105
#  [[ 53   7  10]
#  [  6  11  32]
#  [  5  10 133]]
# --------------------------------------------------------------------------------------
# K value is :  106
#
# Acuuracy Score when k is 106  0.7415730337078652
# Confusion matrix when k is 106
#  [[ 53   6  11]
#  [  5  12  32]
#  [  5  10 133]]
# --------------------------------------------------------------------------------------
# K value is :  107
#
# Acuuracy Score when k is 107  0.7415730337078652
# Confusion matrix when k is 107
#  [[ 53   9   8]
#  [  5  12  32]
#  [  5  10 133]]
# --------------------------------------------------------------------------------------
# K value is :  108
#
# Acuuracy Score when k is 108  0.7453183520599251
# Confusion matrix when k is 108
#  [[ 53   8   9]
#  [  5  12  32]
#  [  5   9 134]]
# --------------------------------------------------------------------------------------
# K value is :  109
#
# Acuuracy Score when k is 109  0.7490636704119851
# Confusion matrix when k is 109
#  [[ 53   9   8]
#  [  5  12  32]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  110
#
# Acuuracy Score when k is 110  0.7528089887640449
# Confusion matrix when k is 110
#  [[ 53   8   9]
#  [  5  13  31]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  111
#
# Acuuracy Score when k is 111  0.7490636704119851
# Confusion matrix when k is 111
#  [[ 53   8   9]
#  [  5  12  32]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  112
#
# Acuuracy Score when k is 112  0.7453183520599251
# Confusion matrix when k is 112
#  [[ 53   8   9]
#  [  5  12  32]
#  [  5   9 134]]
# --------------------------------------------------------------------------------------
# K value is :  113
#
# Acuuracy Score when k is 113  0.7490636704119851
# Confusion matrix when k is 113
#  [[ 53   8   9]
#  [  5  12  32]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  114
#
# Acuuracy Score when k is 114  0.7490636704119851
# Confusion matrix when k is 114
#  [[ 53   9   8]
#  [  5  12  32]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  115
#
# Acuuracy Score when k is 115  0.7490636704119851
# Confusion matrix when k is 115
#  [[ 53  11   6]
#  [  5  12  32]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  116
#
# Acuuracy Score when k is 116  0.7490636704119851
# Confusion matrix when k is 116
#  [[ 53  11   6]
#  [  5  12  32]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  117
#
# Acuuracy Score when k is 117  0.7528089887640449
# Confusion matrix when k is 117
#  [[ 53  11   6]
#  [  5  12  32]
#  [  5   7 136]]
# --------------------------------------------------------------------------------------
# K value is :  118
#
# Acuuracy Score when k is 118  0.7490636704119851
# Confusion matrix when k is 118
#  [[ 53  11   6]
#  [  5  12  32]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  119
#
# Acuuracy Score when k is 119  0.7490636704119851
# Confusion matrix when k is 119
#  [[ 53  12   5]
#  [  5  12  32]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  120
#
# Acuuracy Score when k is 120  0.7453183520599251
# Confusion matrix when k is 120
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  121
#
# Acuuracy Score when k is 121  0.7453183520599251
# Confusion matrix when k is 121
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  122
#
# Acuuracy Score when k is 122  0.7453183520599251
# Confusion matrix when k is 122
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  123
#
# Acuuracy Score when k is 123  0.7415730337078652
# Confusion matrix when k is 123
#  [[ 53  12   5]
#  [  5  10  34]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  124
#
# Acuuracy Score when k is 124  0.7453183520599251
# Confusion matrix when k is 124
#  [[ 53  13   4]
#  [  5  11  33]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  125
#
# Acuuracy Score when k is 125  0.7453183520599251
# Confusion matrix when k is 125
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   8 135]]
# --------------------------------------------------------------------------------------
# K value is :  126
#
# Acuuracy Score when k is 126  0.7490636704119851
# Confusion matrix when k is 126
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   7 136]]
# --------------------------------------------------------------------------------------
# K value is :  127
#
# Acuuracy Score when k is 127  0.7490636704119851
# Confusion matrix when k is 127
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   7 136]]
# --------------------------------------------------------------------------------------
# K value is :  128
#
# Acuuracy Score when k is 128  0.7528089887640449
# Confusion matrix when k is 128
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   6 137]]
# --------------------------------------------------------------------------------------
# K value is :  129
#
# Acuuracy Score when k is 129  0.7528089887640449
# Confusion matrix when k is 129
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   6 137]]
# --------------------------------------------------------------------------------------
# K value is :  130
#
# Acuuracy Score when k is 130  0.7602996254681648
# Confusion matrix when k is 130
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   4 139]]
# --------------------------------------------------------------------------------------
# K value is :  131
#
# Acuuracy Score when k is 131  0.7602996254681648
# Confusion matrix when k is 131
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   4 139]]
# --------------------------------------------------------------------------------------
# K value is :  132
#
# Acuuracy Score when k is 132  0.7602996254681648
# Confusion matrix when k is 132
#  [[ 53  13   4]
#  [  5  11  33]
#  [  5   4 139]]
# --------------------------------------------------------------------------------------
# K value is :  133
#
# Acuuracy Score when k is 133  0.7602996254681648
# Confusion matrix when k is 133
#  [[ 53  13   4]
#  [  5  11  33]
#  [  5   4 139]]
# --------------------------------------------------------------------------------------
# K value is :  134
#
# Acuuracy Score when k is 134  0.7565543071161048
# Confusion matrix when k is 134
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   4 139]]
# --------------------------------------------------------------------------------------
# K value is :  135
#
# Acuuracy Score when k is 135  0.7602996254681648
# Confusion matrix when k is 135
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   3 140]]
# --------------------------------------------------------------------------------------
# K value is :  136
#
# Acuuracy Score when k is 136  0.7602996254681648
# Confusion matrix when k is 136
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   3 140]]
# --------------------------------------------------------------------------------------
# K value is :  137
#
# Acuuracy Score when k is 137  0.7602996254681648
# Confusion matrix when k is 137
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   3 140]]
# --------------------------------------------------------------------------------------
# K value is :  138
#
# Acuuracy Score when k is 138  0.7602996254681648
# Confusion matrix when k is 138
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   3 140]]
# --------------------------------------------------------------------------------------
# K value is :  139
#
# Acuuracy Score when k is 139  0.7602996254681648
# Confusion matrix when k is 139
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   3 140]]
# --------------------------------------------------------------------------------------
# K value is :  140
#
# Acuuracy Score when k is 140  0.7602996254681648
# Confusion matrix when k is 140
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   3 140]]
# --------------------------------------------------------------------------------------
# K value is :  141
#
# Acuuracy Score when k is 141  0.7602996254681648
# Confusion matrix when k is 141
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   3 140]]
# --------------------------------------------------------------------------------------
# K value is :  142
#
# Acuuracy Score when k is 142  0.7565543071161048
# Confusion matrix when k is 142
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   4 139]]
# --------------------------------------------------------------------------------------
# K value is :  143
#
# Acuuracy Score when k is 143  0.7565543071161048
# Confusion matrix when k is 143
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   4 139]]
# --------------------------------------------------------------------------------------
# K value is :  144
#
# Acuuracy Score when k is 144  0.7565543071161048
# Confusion matrix when k is 144
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   4 139]]
# --------------------------------------------------------------------------------------
# K value is :  145
#
# Acuuracy Score when k is 145  0.7565543071161048
# Confusion matrix when k is 145
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   4 139]]
# --------------------------------------------------------------------------------------
# K value is :  146
#
# Acuuracy Score when k is 146  0.7565543071161048
# Confusion matrix when k is 146
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   4 139]]
# --------------------------------------------------------------------------------------
# K value is :  147
#
# Acuuracy Score when k is 147  0.7640449438202247
# Confusion matrix when k is 147
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   2 141]]
# --------------------------------------------------------------------------------------
# K value is :  148
# Acuuracy Score when k is 148  0.7677902621722846
# Confusion matrix when k is 148
#  [[ 52  11   7]
#  [  5  11  33]
#  [  5   1 142]]
# --------------------------------------------------------------------------------------
# K value is :  149
#
# Acuuracy Score when k is 149  0.7677902621722846
# Confusion matrix when k is 149
#  [[ 52  11   7]
#  [  5  11  33]
#  [  5   1 142]]
# --------------------------------------------------------------------------------------
# K value is :  150
#
# Acuuracy Score when k is 150  0.7677902621722846
# Confusion matrix when k is 150
#  [[ 52  11   7]
#  [  5  11  33]
#  [  5   1 142]]
# --------------------------------------------------------------------------------------
# K value is :  151
#
# Acuuracy Score when k is 151  0.7677902621722846
# Confusion matrix when k is 151
#  [[ 52  11   7]
#  [  5  11  33]
#  [  5   1 142]]
# --------------------------------------------------------------------------------------
# K value is :  152
#
# Acuuracy Score when k is 152  0.7640449438202247
# Confusion matrix when k is 152
#  [[ 52  11   7]
#  [  5  10  34]
#  [  5   1 142]]
# --------------------------------------------------------------------------------------
# K value is :  153
#
# Acuuracy Score when k is 153  0.7640449438202247
# Confusion matrix when k is 153
#  [[ 52   9   9]
#  [  5  10  34]
#  [  5   1 142]]
# --------------------------------------------------------------------------------------
# K value is :  154
#
# Acuuracy Score when k is 154  0.7640449438202247
# Confusion matrix when k is 154
#  [[ 52   9   9]
#  [  5  10  34]
#  [  5   1 142]]
# --------------------------------------------------------------------------------------
# K value is :  155
#
# Acuuracy Score when k is 155  0.7640449438202247
# Confusion matrix when k is 155
#  [[ 52   9   9]
#  [  5  10  34]
#  [  5   1 142]]
# --------------------------------------------------------------------------------------
# K value is :  156
#
# Acuuracy Score when k is 156  0.7602996254681648
# Confusion matrix when k is 156
#  [[ 52   9   9]
#  [  5   9  35]
#  [  5   1 142]]
# --------------------------------------------------------------------------------------
# K value is :  157
#
# Acuuracy Score when k is 157  0.7565543071161048
# Confusion matrix when k is 157
#  [[ 52   9   9]
#  [  5   7  37]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  158
#
# Acuuracy Score when k is 158  0.7565543071161048
# Confusion matrix when k is 158
#  [[ 52   9   9]
#  [  5   7  37]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  159
#
# Acuuracy Score when k is 159  0.7565543071161048
# Confusion matrix when k is 159
#  [[ 52   9   9]
#  [  5   7  37]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  160
#
# Acuuracy Score when k is 160  0.7565543071161048
# Confusion matrix when k is 160
#  [[ 52   9   9]
#  [  5   7  37]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  161
#
# Acuuracy Score when k is 161  0.7528089887640449
# Confusion matrix when k is 161
#  [[ 52   9   9]
#  [  5   6  38]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  162
#
# Acuuracy Score when k is 162  0.7528089887640449
# Confusion matrix when k is 162
#  [[ 52   9   9]
#  [  5   6  38]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  163
#
# Acuuracy Score when k is 163  0.7528089887640449
# Confusion matrix when k is 163
#  [[ 52   9   9]
#  [  5   6  38]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  164
#
# Acuuracy Score when k is 164  0.7528089887640449
# Confusion matrix when k is 164
#  [[ 52   9   9]
#  [  5   6  38]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  165
#
# Acuuracy Score when k is 165  0.7528089887640449
# Confusion matrix when k is 165
#  [[ 52   9   9]
#  [  5   6  38]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  166
#
# Acuuracy Score when k is 166  0.7528089887640449
# Confusion matrix when k is 166
#  [[ 52   8  10]
#  [  5   6  38]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  167
#
# Acuuracy Score when k is 167  0.7528089887640449
# Confusion matrix when k is 167
#  [[ 52   7  11]
#  [  5   6  38]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  168
#
# Acuuracy Score when k is 168  0.7528089887640449
# Confusion matrix when k is 168
#  [[ 52   7  11]
#  [  5   6  38]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  169
#
# Acuuracy Score when k is 169  0.7528089887640449
# Confusion matrix when k is 169
#  [[ 52   6  12]
#  [  5   6  38]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  170
#
# Acuuracy Score when k is 170  0.7528089887640449
# Confusion matrix when k is 170
#  [[ 52   6  12]
#  [  5   6  38]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  171
#
# Acuuracy Score when k is 171  0.7528089887640449
# Confusion matrix when k is 171
#  [[ 52   6  12]
#  [  5   6  38]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  172
#
# Acuuracy Score when k is 172  0.7528089887640449
# Confusion matrix when k is 172
#  [[ 52   6  12]
#  [  5   6  38]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  173
#
# Acuuracy Score when k is 173  0.7565543071161048
# Confusion matrix when k is 173
#  [[ 52   6  12]
#  [  5   7  37]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  174
#
# Acuuracy Score when k is 174  0.7490636704119851
# Confusion matrix when k is 174
#  [[ 50   8  12]
#  [  5   7  37]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  175
#
# Acuuracy Score when k is 175  0.7565543071161048
# Confusion matrix when k is 175
#  [[ 52   6  12]
#  [  5   7  37]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  176
#
# Acuuracy Score when k is 176  0.7565543071161048
# Confusion matrix when k is 176
#  [[ 52   6  12]
#  [  5   7  37]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  177
#
# Acuuracy Score when k is 177  0.7565543071161048
# Confusion matrix when k is 177
#  [[ 52   6  12]
#  [  5   7  37]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  178
#
# Acuuracy Score when k is 178  0.7565543071161048
# Confusion matrix when k is 178
#  [[ 52   6  12]
#  [  5   7  37]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  179
#
# Acuuracy Score when k is 179  0.7565543071161048
# Confusion matrix when k is 179
#  [[ 52   6  12]
#  [  5   7  37]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  180
#
# Acuuracy Score when k is 180  0.7490636704119851
# Confusion matrix when k is 180
#  [[ 50   7  13]
#  [  5   7  37]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  181
#
# Acuuracy Score when k is 181  0.7565543071161048
# Confusion matrix when k is 181
#  [[ 52   5  13]
#  [  5   7  37]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  182
#
# Acuuracy Score when k is 182  0.7565543071161048
# Confusion matrix when k is 182
#  [[ 52   5  13]
#  [  5   7  37]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  183
#
# Acuuracy Score when k is 183  0.7565543071161048
# Confusion matrix when k is 183
#  [[ 52   5  13]
#  [  5   7  37]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  184
#
# Acuuracy Score when k is 184  0.7528089887640449
# Confusion matrix when k is 184
#  [[ 51   5  14]
#  [  5   7  37]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  185
#
# Acuuracy Score when k is 185  0.7528089887640449
# Confusion matrix when k is 185
#  [[ 51   5  14]
#  [  5   7  37]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  186
#
# Acuuracy Score when k is 186  0.7490636704119851
# Confusion matrix when k is 186
#  [[ 51   5  14]
#  [  5   6  38]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  187
#
# Acuuracy Score when k is 187  0.7490636704119851
# Confusion matrix when k is 187
#  [[ 51   5  14]
#  [  5   6  38]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  188
#
# Acuuracy Score when k is 188  0.7490636704119851
# Confusion matrix when k is 188
#  [[ 51   5  14]
#  [  5   6  38]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  189
#
# Acuuracy Score when k is 189  0.7453183520599251
# Confusion matrix when k is 189
#  [[ 50   5  15]
#  [  5   6  38]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  190
#
# Acuuracy Score when k is 190  0.7415730337078652
# Confusion matrix when k is 190
#  [[ 50   5  15]
#  [  5   5  39]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  191
#
# Acuuracy Score when k is 191  0.7415730337078652
# Confusion matrix when k is 191
#  [[ 50   5  15]
#  [  5   5  39]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  192
#
# Acuuracy Score when k is 192  0.7415730337078652
# Confusion matrix when k is 192
#  [[ 50   5  15]
#  [  5   5  39]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  193
#
# Acuuracy Score when k is 193  0.7415730337078652
# Confusion matrix when k is 193
#  [[ 50   5  15]
#  [  5   5  39]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  194
#
# Acuuracy Score when k is 194  0.7303370786516854
# Confusion matrix when k is 194
#  [[ 48   7  15]
#  [  5   4  40]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  195
#
# Acuuracy Score when k is 195  0.7228464419475655
# Confusion matrix when k is 195
#  [[ 48   7  15]
#  [  5   2  42]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  196
#
# Acuuracy Score when k is 196  0.7228464419475655
# Confusion matrix when k is 196
#  [[ 48   7  15]
#  [  5   2  42]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  197
#
# Acuuracy Score when k is 197  0.7228464419475655
# Confusion matrix when k is 197
#  [[ 48   7  15]
#  [  5   2  42]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  198
#
# Acuuracy Score when k is 198  0.7228464419475655
# Confusion matrix when k is 198
#  [[ 48   7  15]
#  [  5   2  42]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  199
#
# Acuuracy Score when k is 199  0.7191011235955056
# Confusion matrix when k is 199
#  [[ 48   7  15]
#  [  5   1  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  200
#
# Acuuracy Score when k is 200  0.7191011235955056
# Confusion matrix when k is 200
#  [[ 48   6  16]
#  [  5   1  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  201
#
# Acuuracy Score when k is 201  0.7228464419475655
# Confusion matrix when k is 201
#  [[ 48   6  16]
#  [  5   2  42]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  202
#
# Acuuracy Score when k is 202  0.7228464419475655
# Confusion matrix when k is 202
#  [[ 48   6  16]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  203
#
# Acuuracy Score when k is 203  0.7228464419475655
# Confusion matrix when k is 203
#  [[ 48   6  16]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  204
#
# Acuuracy Score when k is 204  0.7228464419475655
# Confusion matrix when k is 204
#  [[ 48   6  16]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  205
#
# Acuuracy Score when k is 205  0.7228464419475655
# Confusion matrix when k is 205
#  [[ 48   6  16]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  206
#
# Acuuracy Score when k is 206  0.7228464419475655
# Confusion matrix when k is 206
#  [[ 48   6  16]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  207
#
# Acuuracy Score when k is 207  0.7228464419475655
# Confusion matrix when k is 207
#  [[ 48   6  16]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  208
#
# Acuuracy Score when k is 208  0.7228464419475655
# Confusion matrix when k is 208
#  [[ 48   6  16]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  209
#
# Acuuracy Score when k is 209  0.7228464419475655
# Confusion matrix when k is 209
#  [[ 48   6  16]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  210
#
# Acuuracy Score when k is 210  0.7228464419475655
# Confusion matrix when k is 210
#  [[ 48   5  17]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  211
#
# Acuuracy Score when k is 211  0.7228464419475655
# Confusion matrix when k is 211
#  [[ 48   5  17]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  212
#
# Acuuracy Score when k is 212  0.7228464419475655
# Confusion matrix when k is 212
#  [[ 48   4  18]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  213
#
# Acuuracy Score when k is 213  0.7228464419475655
# Confusion matrix when k is 213
#  [[ 48   4  18]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  214
#
# Acuuracy Score when k is 214  0.7228464419475655
# Confusion matrix when k is 214
#  [[ 48   4  18]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  215
#
# Acuuracy Score when k is 215  0.7228464419475655
# Confusion matrix when k is 215
#  [[ 48   4  18]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  216
#
# Acuuracy Score when k is 216  0.7228464419475655
# Confusion matrix when k is 216
#  [[ 48   4  18]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  217
#
# Acuuracy Score when k is 217  0.7228464419475655
# Confusion matrix when k is 217
#  [[ 48   4  18]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  218
#
# Acuuracy Score when k is 218  0.7228464419475655
# Confusion matrix when k is 218
#  [[ 48   4  18]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  219
# Acuuracy Score when k is 219  0.7228464419475655
# Confusion matrix when k is 219
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  220
#
# Acuuracy Score when k is 220  0.7228464419475655
# Confusion matrix when k is 220
#  [[ 48   3  19]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  221
#
# Acuuracy Score when k is 221  0.7228464419475655
# Confusion matrix when k is 221
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  222
#
# Acuuracy Score when k is 222  0.7228464419475655
# Confusion matrix when k is 222
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  223
#
# Acuuracy Score when k is 223  0.7228464419475655
# Confusion matrix when k is 223
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  224
#
# Acuuracy Score when k is 224  0.7228464419475655
# Confusion matrix when k is 224
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  225
#
# Acuuracy Score when k is 225  0.7228464419475655
# Confusion matrix when k is 225
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  226
#
# Acuuracy Score when k is 226  0.7228464419475655
# Confusion matrix when k is 226
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  227
#
# Acuuracy Score when k is 227  0.7228464419475655
# Confusion matrix when k is 227
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  228
#
# Acuuracy Score when k is 228  0.7228464419475655
# Confusion matrix when k is 228
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  229
#
# Acuuracy Score when k is 229  0.7228464419475655
# Confusion matrix when k is 229
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  230
#
# Acuuracy Score when k is 230  0.7228464419475655
# Confusion matrix when k is 230
#  [[ 48   1  21]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  231
#
# Acuuracy Score when k is 231  0.7228464419475655
# Confusion matrix when k is 231
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  232
#
# Acuuracy Score when k is 232  0.7228464419475655
# Confusion matrix when k is 232
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  233
#
# Acuuracy Score when k is 233  0.7228464419475655
# Confusion matrix when k is 233
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  234
#
# Acuuracy Score when k is 234  0.7228464419475655
# Confusion matrix when k is 234
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  235
#
# Acuuracy Score when k is 235  0.7228464419475655
# Confusion matrix when k is 235
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  236
#
# Acuuracy Score when k is 236  0.7228464419475655
# Confusion matrix when k is 236
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  237
#
# Acuuracy Score when k is 237  0.7228464419475655
# Confusion matrix when k is 237
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  238
#
# Acuuracy Score when k is 238  0.7228464419475655
# Confusion matrix when k is 238
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  239
#
# Acuuracy Score when k is 239  0.7228464419475655
# Confusion matrix when k is 239
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  240
#
# Acuuracy Score when k is 240  0.7228464419475655
# Confusion matrix when k is 240
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  241
#
# Acuuracy Score when k is 241  0.7228464419475655
# Confusion matrix when k is 241
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  242
#
# Acuuracy Score when k is 242  0.7228464419475655
# Confusion matrix when k is 242
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  243
#
# Acuuracy Score when k is 243  0.7228464419475655
# Confusion matrix when k is 243
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  244
#
# Acuuracy Score when k is 244  0.7191011235955056
# Confusion matrix when k is 244
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  245
#
# Acuuracy Score when k is 245  0.7191011235955056
# Confusion matrix when k is 245
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  246
#
# Acuuracy Score when k is 246  0.7191011235955056
# Confusion matrix when k is 246
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  247
#
# Acuuracy Score when k is 247  0.7191011235955056
# Confusion matrix when k is 247
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  248
#
# Acuuracy Score when k is 248  0.7191011235955056
# Confusion matrix when k is 248
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  249
#
# Acuuracy Score when k is 249  0.7191011235955056
# Confusion matrix when k is 249
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  250
#
# Acuuracy Score when k is 250  0.7191011235955056
# Confusion matrix when k is 250
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  251
#
# Acuuracy Score when k is 251  0.7191011235955056
# Confusion matrix when k is 251
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  252
#
# Acuuracy Score when k is 252  0.7191011235955056
# Confusion matrix when k is 252
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  253
#
# Acuuracy Score when k is 253  0.7191011235955056
# Confusion matrix when k is 253
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  254
# Acuuracy Score when k is 254  0.7191011235955056
# Confusion matrix when k is 254
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  255
#
# Acuuracy Score when k is 255  0.7191011235955056
# Confusion matrix when k is 255
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  256
#
# Acuuracy Score when k is 256  0.7191011235955056
# Confusion matrix when k is 256
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  257
#
# Acuuracy Score when k is 257  0.7191011235955056
# Confusion matrix when k is 257
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  258
#
# Acuuracy Score when k is 258  0.7191011235955056
# Confusion matrix when k is 258
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  259
#
# Acuuracy Score when k is 259  0.7191011235955056
# Confusion matrix when k is 259
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  260
#
# Acuuracy Score when k is 260  0.7191011235955056
# Confusion matrix when k is 260
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  261
#
# Acuuracy Score when k is 261  0.7191011235955056
# Confusion matrix when k is 261
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  262
#
# Acuuracy Score when k is 262  0.7191011235955056
# Confusion matrix when k is 262
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  263
#
# Acuuracy Score when k is 263  0.7191011235955056
# Confusion matrix when k is 263
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  264
#
# Acuuracy Score when k is 264  0.7191011235955056
# Confusion matrix when k is 264
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  265
#
# Acuuracy Score when k is 265  0.7191011235955056
# Confusion matrix when k is 265
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# --------------------------------------------------------------------------------------
# K value is :  266
#
# Acuuracy Score when k is 266  0.7153558052434457
# Confusion matrix when k is 266
#  [[ 47   0  23]
#  [  4   1  44]
#  [  5   0 143]]
